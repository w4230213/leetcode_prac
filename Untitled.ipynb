# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame([[1,1,1], [2,2,2], [3,3,3]], columns=list('ABC'))

# %%
a = np.random.random_sample(20).reshape(4,5)

# %%
a
# Out:
# array([[0.43720955, 0.82860881, 0.87496993, 0.08799169, 0.29052544],
#        [0.22500935, 0.24886481, 0.01863285, 0.62577003, 0.80620081],
#        [0.91923253, 0.92568534, 0.58862919, 0.14898654, 0.22807643],
#        [0.74110063, 0.93502918, 0.22354332, 0.463116  , 0.86355042]])

# %%
b = np.random.random_sample(20).reshape(4,5)
b
# Out:
# array([[0.26582275, 0.06211254, 0.61319483, 0.30622251, 0.56961897],
#        [0.18220902, 0.77755199, 0.73907804, 0.70183683, 0.36916327],
#        [0.55905472, 0.00641041, 0.75958389, 0.376896  , 0.86306028],
#        [0.13788007, 0.60479553, 0.7269844 , 0.47338581, 0.2652171 ]])

# %%
maska = a>0.5
maska
# Out:
# array([[False,  True,  True, False, False],
#        [False, False, False,  True,  True],
#        [ True,  True,  True, False, False],
#        [ True,  True, False, False,  True]])

# %%
maskb = b>0.5
maskb
# Out:
# array([[False, False,  True, False,  True],
#        [False,  True,  True,  True, False],
#        [ True, False,  True, False,  True],
#        [False,  True,  True, False, False]])

# %%
maska | maskb
# Out:
# array([[False,  True,  True, False,  True],
#        [False,  True,  True,  True,  True],
#        [ True,  True,  True, False,  True],
#        [ True,  True,  True, False,  True]])
